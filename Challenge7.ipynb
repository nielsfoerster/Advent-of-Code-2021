# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('data7.txt',header=None).T

# %%
data.mean()
# Out:
# 0    475.563
# dtype: float64

# %%
for d in data:
    rmse=(d-np.mean(data))**2)

# %%
rmse
# Out:
# 0    15.038623
# dtype: float64

# %%
plt.scatter(y=data,x=range(0,1000))
